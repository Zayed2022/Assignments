# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?
# ### Flask Framework:
#
# Flask is a lightweight WSGI (Web Server Gateway Interface) web application framework in Python.
# It is designed to be simple and easy to use, allowing developers to build web applications quickly and with minimal code.
# Flask is considered a micro-framework because it does not require particular tools or libraries and has no database abstraction layer, form validation, or any other components where pre-existing third-party libraries provide common functions.
# Advantages of Flask Framework:
# Lightweight and easy to get started.
# Built-in development server and debugger.
# Integrated support for unit testing.
# Jinja2 templating.
# RESTful request dispatching.
# Unicode-based.
# Extensively documented.
# Extensions available for complex functionalities.

# %% [markdown]
# ## Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.
# ## Here's a simple Flask application that displays "Hello World!!":
#
# from flask import Flask
#
# Create a Flask application
# app = Flask(__name__)
#
# Define a route for the default URL path ('/')
# @app.route('/')
# def hello():
#     return 'Hello World!!'
#
# if __name__ == '__main__':
#     app.run(debug=True)

# %% [markdown]
# ![Screenshot 2024-06-02 132302.png](attachment:a0da6add-485a-40db-8a2d-34d0a177bee4.png)

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?
# ### App Routing in Flask:
#
# App routing in Flask refers to mapping URLs to functions in your Python code.
# It allows you to define different URLs that users can visit in your web application.
# Each route has a function that gets executed when that route is requested by a client (browser).
# Why do we use app routes?
#
# App routes allow us to create different URLs for different parts of our application.
# They provide a way to structure your application and define how users will interact with it.
# Routing allows for clean, readable, and maintainable code in web applications.

# %%
### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
Here's the code to achieve this in Flask:

# from flask import Flask

# Create a Flask application
# app = Flask(__name__)

# Define a route for the '/welcome' URL path
# @app.route('/welcome')
# def welcome():
#     return 'Welcome to ABC Corporation'
# Define a route for the '/' URL path
# @app.route('/')
# def company_details():
#     return '''
#     <h1>Company Name: ABC Corporation</h1>
#     <p>Location: India</p>
#     <p>Contact Detail: 999-999-9999</p>
#     '''

# if __name__ == '__main__':
#     app.run(debug=True)
# Here's how the output looks:

# %% [markdown]
# ![Screenshot 2024-06-02 132947.png](attachment:5399a84d-4bba-4f44-8f8e-010c1b9b5500.png)

# %% [markdown]
# ![Screenshot 2024-06-02 132720.png](attachment:22a8bb98-4df4-4f80-b176-839a56f6adef.png)

# %%
##Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.
##url_for() Function in Flask:

# The url_for() function in Flask is used to build URLs for functions that are defined in your Flask application.
# Here's an example demonstrating the use of url_for():

from flask import Flask, url_for, redirect

app = Flask(__name__)


@app.route('/')
def index():
    welcome_url = url_for('welcome')
    return f'<h1>Welcome to my Flask App!</h1><p>Visit the <a href="{welcome_url}">Welcome Page</a></p>'

@app.route('/welcome')
def welcome():
    return 'Welcome to ABC Corporation'

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py:3558: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
